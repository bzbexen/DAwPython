# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %matplotlib inline  
# gorsellerin uyumlu guzel gorunumu icin 


plt.rcParams["figure.figsize"] = (10,6) 
# grafiklerin boyutu default (10,6) gelir

sns.set_style("whitegrid")
#extra belirtilmedikce zeminler beyaz grid gelir 
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# rakamlar .dan sonra 3 basamakli gelir 

pd.options.display.max_rows = 150
#gostermek istedigimiz satir sayisi 

pd.options.display.max_columns = 100
#gostermek istedigimiz sutun sayisi

# %%
df = pd.read_csv("sales_082020.csv")
df.head()
# Out:
#       buyer_id buyer_country seller_id seller_country  product_code  \
# 0   qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1   o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2   sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3   o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4   o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# 5   bf6dqe8we7            GB  dpkx192v             GB  cmwn68orhjq8
# 6   o79pns1qwo            GB  9p2ansc9             GB  dsz1fy32ry6y
# 7   bob9rlo4lb            GB  9p2ansc9             GB  jfncu4dmfnoc
# 8   bob9rlo4lb            GB  9p2ansc9             GB  ssmpsnfvopu9
# 9   thxau27e0a            GB  9p2ansc9             GB  0dv7zg0lu2xc
# 10  762bgx2nhz            GB  9p2ansc9             GB  noptuewx9l22
# 11  762bgx2nhz            GB  9p2ansc9             GB  3omdouiqh11l
# 12  p9vxp94nfh            IE  9p2ansc9             GB  95a5rc0jjtbz
# ...

# %%
df.shape
# Out:
# (237671, 10)

# %%
# 1. How many rows in the sales dataset?(Just write numbers) *
df.seller_id.count()
# Out:
# 237671

# %%
# 3. What is the total number of sellers?(Just write numbers) *
df.seller_id.value_counts()
# Out:
# pzsiehl0    703
# wd3rgi3q    525
# j21w87xy    500
# dbm0o9qu    436
# hbtm3tdy    316
#            ...
# t6y69pym      1
# qz0lqyy9      1
# 9945rt9c      1
# rsa6bzpo      1
# 71tp919p      1
# Name: seller_id, Length: 114227, dtype: int64

# %%
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
# 4. What is the total value of sales in EUR?(Just write numbers) 
df.groupby("currency")["price"].sum()
# Out:
# currency
# AUD    325563.440
# BRL        34.920
# CAD     65101.800
# CHF      5974.740
# CZK      3923.180
# DKK      4853.440
# EUR    275837.690
# GBP   3449449.490
# HKD       108.130
# HUF     36919.180
# ILS        33.800
# JPY     39722.660
# MXN       389.470
# MYR       263.300
# NOK      3168.340
# NZD     10532.850
# PLN       693.360
# SEK     10903.220
# SGD       443.370
# THB      1223.720
# TWD        42.810
# USD   2504544.820
# Name: price, dtype: float64

# %%
df.head(100)
# Out:
#       buyer_id buyer_country seller_id seller_country  product_code  \
# 0   qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1   o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2   sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3   o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4   o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# 5   bf6dqe8we7            GB  dpkx192v             GB  cmwn68orhjq8
# 6   o79pns1qwo            GB  9p2ansc9             GB  dsz1fy32ry6y
# 7   bob9rlo4lb            GB  9p2ansc9             GB  jfncu4dmfnoc
# 8   bob9rlo4lb            GB  9p2ansc9             GB  ssmpsnfvopu9
# 9   thxau27e0a            GB  9p2ansc9             GB  0dv7zg0lu2xc
# 10  762bgx2nhz            GB  9p2ansc9             GB  noptuewx9l22
# 11  762bgx2nhz            GB  9p2ansc9             GB  3omdouiqh11l
# 12  p9vxp94nfh            IE  9p2ansc9             GB  95a5rc0jjtbz
# ...

# %%
# 5. Which brand has the highest number of purchases?(Write down brand as in dataset, answer is case sensitive) 
df["brand"].value_counts().sort_values()
# Out:
# Liam Hodges              1
# Seychelles               1
# Tumi                     1
# Aries Arise              1
# Saturdays NYC            1
#                       ...
# Adidas                3905
# PrettyLittle Thing    4136
# Topshop               4561
# Brandy Melville       5065
# Nike                  9575
# Name: brand, Length: 1134, dtype: int64

# %%
df1= df.loc[(df["category"]=="Jewellery")]
df1
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 23      94lh9gu3bu            US  dhsa2q6o             US  1m846u2l2dyl
# 48      u8da411658            AU  qn7p4cv2             AU  dd4d4p2h4us2
# 49      9exo58j839            AU  qn7p4cv2             AU  6nogqtmgfjsn
# 50      9exo58j839            AU  qn7p4cv2             AU  w5ixs8y20z3n
# 51      9exo58j839            AU  qn7p4cv2             AU  g5usn39z8b7u
# ...            ...           ...       ...            ...           ...
# 237545  rabu7nz8gn            US  rv5nmiwq             US  ikfosml5pjas
# 237568  ytjobx2wzg            GB  qib5sh0l             GB  tn00dvezdp43
# 237569  ytjobx2wzg            GB  qib5sh0l             GB  eykndnmcb4g6
# 237616  p0jol2ieus            US  4pi8qok2             US  0ipj5zmes1cu
# 237643  q86525x69t            GB  33hffrhq             GB  426jwzj6b2uz
#
#          category brand currency  price        date
# ...

# %%
#  6. How many items in the “Jewelry” category have no brand?(Just write numbers) * 
missing_values = np.where(df1["brand"].isna())[0]
len(missing_values)
# Out:
# 13525

# %%
df[df.category== "Jewellery"]["brand"].value_counts(dropna=False)
# Out:
# NaN                     13525
# PANDORA                   493
# Brandy Melville           190
# Vivienne Westwood          94
# Unbranded                  56
# Tiffany & Co.              56
# Michael Kors               43
# Swarovski                  33
# Hot Topic                  28
# Topshop                    27
# Thomas Sabo                27
# ALEX AND ANI               26
# Forever 21                 22
# Dior                       21
# Links of London            16
# Emporio Armani             15
# New Look                   15
# ASOS                       13
# Marc Jacobs                13
# Gucci                      12
# Chanel                     10
# Ted Baker                  10
# Anthropologie              10
# Olivia Burton               9
# & Other Stories             7
# H&M                         7
# Cartier                     6
# Guess                       6
# Kendra Scott                6
# Primark                     6
# Alexander McQueen           6
# ...

# %%
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
# 7. How many brands have number of transactions between 35 and 55 (inclusive)?(Just write numbers)
df["brand"].value_counts()
# Out:
# Nike                  9575
# Brandy Melville       5065
# Topshop               4561
# PrettyLittle Thing    4136
# Adidas                3905
#                       ...
# Privacy Please           1
# LPA                      1
# Police                   1
# Rock and Republic        1
# Liam Hodges              1
# Name: brand, Length: 1134, dtype: int64

# %%
(df["brand"].value_counts()>=35)&(df["brand"].value_counts()<=55).
# Out:
# Nike                  False
# Brandy Melville       False
# Topshop               False
# PrettyLittle Thing    False
# Adidas                False
#                       ...
# Privacy Please        False
# LPA                   False
# Police                False
# Rock and Republic     False
# Liam Hodges           False
# Name: brand, Length: 1134, dtype: bool

# %%
df.brand.value_counts(dropna=False)[[35:55]]
# Out:
#   File "<ipython-input-207-9ab36fff7026>", line 1
#     df.brand.value_counts(dropna=False)[[35:55]]
#                                            ^
# SyntaxError: invalid syntax

# %%
[(df.groupby(['brand']).brand.value_counts().sort_values(ascending=False)<=55)&(df.groupby(['brand']).brand.value_counts().sort_values(ascending=False)>=35)].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-181-2b5e2b2b4ba4> in <module>
# ----> 1 [(df.groupby(['brand']).brand.value_counts().sort_values(ascending=False)<=55)&(df.groupby(['brand']).brand.value_counts().sort_values(ascending=False)>=35)].count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
df["date"]= pd.to_datetime(df.date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 18.1+ MB

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    object
#  2   rate      220 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 5.3+ KB

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    datetime64[ns]
#  2   rate      220 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 5.3+ KB

# %%
# 8. How many pairs of shoes were purchased by Australian (AU) buyers?(Just write numbers)
df.loc[(df["category"]=="Shoes")& (df["buyer_country"]=="AU")].shape[0]
# Out:
# 658

# %%
df[df.buyer_country== "AU"].groupby("category").count()
# Out:
#                    buyer_id  buyer_country  seller_id  seller_country  \
# category
# Accessories             708            708        708             708
# Art                      46             46         46              46
# Beauty                  134            134        134             134
# Books & magazines        29             29         29              29
# Bottoms - Mens          139            139        139             139
# Bottoms - Womens       1168           1168       1168            1168
# Dresses                 862            862        862             862
# Film                     44             44         44              44
# Home                     21             21         21              21
# Jewellery               518            518        518             518
# Kids                     11             11         11              11
# Lingerie                211            211        211             211
# ...

# %%
rates = pd.read_csv("currency_rates_082020_EUR.csv")
rates.head(50)
# Out:
#    currency       date  rate
# 0       EUR   8/1/2020 1.000
# 1       EUR   8/2/2020 1.000
# 2       EUR   8/3/2020 1.000
# 3       EUR   8/4/2020 1.000
# 4       EUR   8/5/2020 1.000
# 5       EUR   8/6/2020 1.000
# 6       EUR   8/7/2020 1.000
# 7       EUR   8/8/2020 1.000
# 8       EUR   8/9/2020 1.000
# 9       EUR  8/10/2020 1.000
# 10      GBP   8/1/2020 0.900
# 11      GBP   8/2/2020 0.899
# 12      GBP   8/3/2020 0.899
# 13      GBP   8/4/2020 0.903
# 14      GBP   8/5/2020 0.904
# 15      GBP   8/6/2020 0.904
# 16      GBP   8/7/2020 0.903
# 17      GBP   8/8/2020 0.903
# 18      GBP   8/9/2020 0.903
# 19      GBP  8/10/2020 0.898
# 20      USD   8/1/2020 1.178
# 21      USD   8/2/2020 1.178
# 22      USD   8/3/2020 1.176
# 23      USD   8/4/2020 1.181
# 24      USD   8/5/2020 1.187
# 25      USD   8/6/2020 1.188
# 26      USD   8/7/2020 1.179
# 27      USD   8/8/2020 1.179
# 28      USD   8/9/2020 1.178
# 29      USD  8/10/2020 1.174
# 30      AUD   8/1/2020 1.649
# ...

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP 19.110 2020-08-03
# 1         Outerwear  Adidas Originals      GBP 15.920 2020-08-09
# 2       Tops - Mens               NaN      GBP  6.370 2020-08-07
# 3       Tops - Mens          Berghaus      GBP 25.270 2020-08-09
# 4  Bottoms - Womens               NaN      GBP  8.900 2020-08-09

# %%
# 9. Which brand has the highest average transaction value? (Just write brand name)
df2.groupby("brand").agg({"price_uni":"mean"}).idxmax()
# Out:
# price_uni    Goyard
# dtype: object

# %%
brand_mean = df.groupby("brand").mean()
brand_mean.sort_values(by="price", ascending=False)
# Out:
#                          price
# brand
# Goyard                 339.363
# Loewe                  302.043
# Loeffler Randall       244.840
# Craig Green            239.940
# Walter Van Beirendonck 216.180
# ...                        ...
# MUA                      4.687
# Max Factor               3.912
# Bronica                  3.786
# 36572                    1.120
# 360 Cashmere             1.120
#
# [1134 rows x 1 columns]

# %%
#10.What s the total value of items purchased by GB buyers from GB sellers? (Just write numbers)
df2.loc[(df2["buyer_country"]=="GB")& (df2["seller_country"]=="GB")].head(150)
# Out:
#        buyer_id buyer_country seller_id seller_country  product_code  \
# 0    qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1    o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2    sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3    o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4    o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# 5    bf6dqe8we7            GB  dpkx192v             GB  cmwn68orhjq8
# 6    o79pns1qwo            GB  9p2ansc9             GB  dsz1fy32ry6y
# 7    bob9rlo4lb            GB  9p2ansc9             GB  jfncu4dmfnoc
# 8    bob9rlo4lb            GB  9p2ansc9             GB  ssmpsnfvopu9
# 9    thxau27e0a            GB  9p2ansc9             GB  0dv7zg0lu2xc
# 10   762bgx2nhz            GB  9p2ansc9             GB  noptuewx9l22
# 11   762bgx2nhz            GB  9p2ansc9             GB  3omdouiqh11l
# 13   75ud9f728b            GB  9p2ansc9             GB  xlv1zz6wx7wd
# ...

# %%
df2.loc[(df2["buyer_country"]=="GB")& (df2["seller_country"]=="GB")]["price_uni"].sum()
# Out:
# 3526745.0331292334

# %%
# 11. What percentage of US sellers' transactions were purchased by US buyers? (Just write percentage)
df.loc[(df["buyer_country"]=="US")& (df["seller_country"]=="US")].shape[0]
# Out:
# 80658

# %%
(df.loc[(df["buyer_country"]=="US")& (df["seller_country"]=="US")].shape[0])/len(df)*100
# Out:
# 33.93682864127302

# %%
us = df[(df["buyer_country"]=="US")&(df["seller_country"]=="US")].shape[0]
total = df[df["seller_country"]=="US"].shape[0]
us/total*100
# Out:
# 98.23044415486353

# %%
df.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date
# 0           Dresses               NaN      GBP 19.110 2020-08-03
# 1         Outerwear  Adidas Originals      GBP 15.920 2020-08-09
# 2       Tops - Mens               NaN      GBP  6.370 2020-08-07
# 3       Tops - Mens          Berghaus      GBP 25.270 2020-08-09
# 4  Bottoms - Womens               NaN      GBP  8.900 2020-08-09

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 18.1+ MB

# %%
rates["date"]= pd.to_datetime(rates.date)

# %%
rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   currency  220 non-null    object
#  1   date      220 non-null    datetime64[ns]
#  2   rate      220 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 5.3+ KB

# %%
rates.head()
# Out:
#   currency       date  rate
# 0      EUR 2020-08-01 1.000
# 1      EUR 2020-08-02 1.000
# 2      EUR 2020-08-03 1.000
# 3      EUR 2020-08-04 1.000
# 4      EUR 2020-08-05 1.000

# %%
df2= pd.merge(df,rates, on=["currency","date"],how="left", suffixes=["_left", "_right"] )
df2
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price       date  rate
# ...

# %%
df2["price_uni"]=(df2.price) / (df2.rate)

# %%
df2.head()
# Out:
#      buyer_id buyer_country seller_id seller_country  product_code  \
# 0  qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1  o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2  sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3  o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4  o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
#
#            category             brand currency  price       date  rate  \
# 0           Dresses               NaN      GBP 19.110 2020-08-03 0.899
# 1         Outerwear  Adidas Originals      GBP 15.920 2020-08-09 0.903
# 2       Tops - Mens               NaN      GBP  6.370 2020-08-07 0.903
# 3       Tops - Mens          Berghaus      GBP 25.270 2020-08-09 0.903
# 4  Bottoms - Womens               NaN      GBP  8.900 2020-08-09 0.903
#
#    price_uni
# 0     21.249
# 1     17.634
# 2      7.055
# 3     27.991
# 4      9.858

# %%
df2.groupby("brand").agg({"price_uni":"mean"}).idxmax()
# Out:
# price_uni    Goyard
# dtype: object

# %%
df2["price_uni"].sum()
# Out:
# 6471510.8224988775
